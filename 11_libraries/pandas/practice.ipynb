# %%
import pandas as pd

# %%
data=[1,2,3,4]
a=pd.Series(data,index=['A','B','C','D'])
print(a)
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data={
    "Name":['John','Mary','Mia','opea'],
    'Age':[25,23,74,52],
    "salary":[25000,20000,500000,520000]
}

df=pd.DataFrame(data)
print(df)
# Out:
#    Name  Age  salary
# 0  John   25   25000
# 1  Mary   23   20000
# 2   Mia   74  500000
# 3  opea   52  520000

# %%
df=pd.read_csv("student_scores.csv")
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
df=pd.read_excel("banking Data.xlsx")
print(df)
# Out:
#      Client ID              Name  Age     Sex  Location ID Joined Bank  \
# 0     PKR81288     Raymond Mills   24    Male        34324  2019-05-06
# 1     PKR65833     Julia Spencer   23    Male        42205  2001-12-10
# 2     PKR47499    Stephen Murray   27  Female         7314  2010-01-25
# 3     PKR72498    Virginia Garza   40    Male        34594  1993-03-28
# 4     PKR60181   Melissa Sanders   46  Female        41269  2012-07-20
# ...        ...               ...  ...     ...          ...         ...
# 2995  PKR66827         Earl Hall   82  Female         8760  2014-10-09
# 2996  PKR40556  Billy Williamson   44  Female        32837  2009-02-05
# 2997  PKR72414      Victor Black   70  Female        36088  2009-12-29
# 2998  PKR46652       Andrew Ford   56  Female        24871  2006-02-13
# 2999  PKR40216        Amy Nguyen   79  Female        38518  2005-12-08
#
#           Banking Contact Nationality                     Occupation  \
# ...

# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4],index=['A','B','C','D'])
print(s)
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data={
    'names':['uri','mecha','bosa','nera'],
    'age':[25,23,74,52]
}
df=pd.DataFrame(data,index=['A','B','C','D'])
df
# Out:
#    names  age
# A    uri   25
# B  mecha   23
# C   bosa   74
# D   nera   52

# %%
import pandas as pd
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df[['Survived','Fare']]
# Out:
#      Survived     Fare
# 0           0   7.2500
# 1           1  71.2833
# 2           1   7.9250
# 3           1  53.1000
# 4           0   8.0500
# ..        ...      ...
# 886         0  13.0000
# 887         1  30.0000
# 888         0  23.4500
# 889         1  30.0000
# 890         0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Basic mathematical operations

# %%
df['Survived'].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64>

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Fare'].min()
# Out:
# 0.0

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df['Fare'].std()
# Out:
# 49.6934285971809

# %%
df['Fare'].count()
# Out:
# 891

# %% [markdown]
# ## data maniplations

# %%
df['Sex']=='male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ### mulltiple  conditions
#
# df [(df['column']condition1)& (df['column']conndition)& (df['column']condition)]

# %%
df[ (df['Sex']=='female')& (df['Fare']>50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# ..           ...       ...     ...
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Age'].count()
# Out:
# 714

# %%
df['double_price']=df['Fare']*2

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'double_price'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  double_price
# 0      0         A/5 21171   7.2500   NaN        S       14.5000
# 1      0          PC 17599  71.2833   C85        C      142.5666
# 2      0  STON/O2. 3101282   7.9250   NaN        S       15.8500
# ...

# %%
import pymysql as sql

conn=sql.connect(
    host='relational.fit.cvut.cz',
    user='quest',
    password='relational',
    port=3306

)
c=conn.cursor()
c.execute("select tables")

# %%
pwd
# Out:
# 'f:\\courses\\Python\\Python_Workspace\\modern-python-101\\libraries\\pandas'

# %%
# %cd f:\\courses\\Python\\Python_Workspace\\modern-python-101\\libraries\\pandas\\exporting_results
# Out:
# f:\courses\Python\Python_Workspace\modern-python-101\libraries\pandas\exporting_results

# %%
pwd
# Out:
# 'f:\\courses\\Python\\Python_Workspace\\modern-python-101\\libraries\\pandas\\exporting_results'

# %%
pwd
# Out:
# 'f:\\courses\\Python\\Python_Workspace\\modern-python-101\\libraries\\pandas\\exporting_results'

# %%
pwd
# Out:
# 'f:\\courses\\Python\\Python_Workspace\\modern-python-101\\libraries\\pandas\\exporting_results'

# %%
cd ..
# Out:
# f:\courses\Python\Python_Workspace\modern-python-101\libraries\pandas

# %%
import psycopg2

def connect_to_postgresql():
    try:
        # Connect to the PostgreSQL database (replace the placeholders with your own credentials)
        conn = psycopg2.connect(
            host="127.0.0.1",
            database="testdb",
            user="postgres",
            password="root",
            port=5432
        )

        if conn:
            print("Connected to PostgreSQL database.")

            # Create a cursor object to interact with the database
            cursor = conn.cursor()

            # Execute a simple query
            query = "SELECT * FROM your_table"
            cursor.execute(query)

            # Fetch and print the query results
            rows = cursor.fetchall()
            for row in rows:
                print(row)

            # Close the cursor and connection
            cursor.close()
            conn.close()
            print("Connection closed.")
        else:
            print("Failed to connect to PostgreSQL database.")

    except psycopg2.Error as e:
        print(f"Error occurred: {e}")

# Example usage
connect_to_postgresql()
# Out:
# Connected to PostgreSQL database.
# Error occurred: relation "your_table" does not exist
# LINE 1: SELECT * FROM your_table
#                       ^

# %%
import pandas as pd

excel_file = 'ESD.xlsx'  # Replace 'your_excel_file.xlsx' with the path to your Excel file
df = pd.read_excel(excel_file)

# %%
df.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
print(df.dtypes.to_string())
# Out:
# EEID                     object
# Full Name                object
# Job Title                object
# Department               object
# Business Unit            object
# Gender                   object
# Ethnicity                object
# Age                       int64
# Hire Date        datetime64[ns]
# Annual Salary             int64
# Bonus %                 float64
# Country                  object
# City                     object
# Exit Date        datetime64[ns]

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# Step 1: Read Excel file into a pandas DataFrame
excel_file = 'ESD.xlsx'  # Replace 'your_excel_file.xlsx' with the path to your Excel file
df = pd.read_excel(excel_file)

# Step 2: Establish a connection to your PostgreSQL database
DB_HOST = 'localhost'  # Replace 'your_host' with your PostgreSQL host
DB_NAME = 'testdb'  # Replace 'your_database' with your PostgreSQL database name
DB_USER = 'postgres'  # Replace 'your_username' with your PostgreSQL username
DB_PASSWORD = 'root'  # Replace 'your_password' with your PostgreSQL password

# Construct the database URL
DB_URL = f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}'

# Create an engine to connect to the database
engine = create_engine(DB_URL)

# Step 3: Insert data from DataFrame into PostgreSQL table
table_name = 'ESD'  # Replace 'your_table_name' with the name of your PostgreSQL table

try:
    df.to_sql(table_name, engine, index=False, if_exists='append')
    print("Data successfully pushed to PostgreSQL!")
except Exception as e:
    print("Error:", e)
# Out:
# Data successfully pushed to PostgreSQL!
